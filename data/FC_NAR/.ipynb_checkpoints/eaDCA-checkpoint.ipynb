# %%
name="RF01734" #choose the family

using FCSeqTools
natural_sequences=do_number_matrix_rna(do_letter_matrix("./RNA_MSA/$(name).txt"),0.2)  ;
# Out:
# 2345×65 Matrix{Int8}:
#  2  2  3  3  2  1  1  2  2  3  3  2  3  …  4  2  2  4  1  2  1  2  4  4  2  4
#  2  4  4  1  2  1  3  2  1  3  3  2  3     4  2  2  4  1  2  2  2  3  1  1  2
#  2  4  4  4  2  1  3  2  1  3  3  2  3     4  2  2  4  1  2  2  3  1  1  4  1
#  2  3  4  3  1  1  2  2  2  3  3  2  3     4  2  2  4  1  2  2  2  4  1  2  1
#  2  3  1  1  4  1  1  1  1  3  3  2  3     4  2  2  4  1  2  2  3  3  4  3  1
#  1  2  3  2  1  1  4  1  1  3  3  2  3  …  4  2  2  4  1  2  2  1  3  1  2  4
#  2  2  3  3  2  1  1  2  3  3  3  2  3     4  2  2  4  1  2  4  2  4  4  2  4
#  4  4  2  1  1  1  1  2  3  3  3  2  3     4  2  2  4  1  2  1  2  4  4  2  2
#  1  1  2  1  2  3  1  4  1  3  3  2  3     4  2  2  4  1  2  2  1  3  4  4  4
#  1  4  4  4  1  3  2  1  1  3  3  2  3     4  2  2  4  3  2  3  1  4  1  2  3
#  4  2  3  2  2  4  3  2  4  3  3  1  3  …  3  2  2  4  3  2  1  4  3  2  2  2
#  1  1  4  1  1  1  3  1  4  3  3  2  3     4  2  2  4  1  2  4  1  4  4  2  2
# ...

# %%
Random.seed!(1)
score,likelihood_gain,generated_sequences,Jij,h,contact_list,site_degree,edge_list=eaDCA(5,0.1,12000,natural_sequences, "Training_Example_$(name).txt");
# Out:
# Fully connected model has 2485 edges and a score around ~ 0.95
#
# [28  40]  iter: 1   edges: 1   0.04%
# [30  38]  iter: 2   edges: 2   0.08%
# [12  22]  iter: 3   edges: 3   0.12%
# [48  62]  iter: 4   edges: 4   0.16%
# [4  67]  iter: 5   edges: 5   0.2%
# [27  41]  iter: 6   edges: 6   0.24%
# [2  69]  iter: 7   edges: 7   0.28%
# [49  61]  iter: 8   edges: 8   0.32%
# [3  68]  iter: 9   edges: 9   0.36%
# [6  65]  iter: 10   edges: 10   0.4%
# [5  66]  iter: 11   edges: 11   0.44%
# [47  63]  iter: 12   edges: 12   0.48%
# [7  64]  iter: 13   edges: 13   0.52%
# [29  39]  iter: 14   edges: 14   0.56%
# [11  23]  iter: 15   edges: 15   0.6%   Score = 0.613    <E> = 70.08    log(Z) = 0.09   S = 70.17
# [26  42]  iter: 16   edges: 16   0.64%
# [1  70]  iter: 17   edges: 17   0.68%
# [50  60]  iter: 18   edges: 18   0.72%
# [36  37]  iter: 19   edges: 19   0.76%
# [35  36]  iter: 20   edges: 20   0.8%
# [13  21]  iter: 21   edges: 21   0.85%
# [15  46]  iter: 22   edges: 22   0.89%
# ...

# %%
print_fasta_to_file_rna(generated_sequences,"$(name)_artificial_sequences.txt")
